# %%
import json

# %%
d = {"name": "Shubham", "age": 24, "education": None}

# %%
data = json.dumps(d)

# %%
data
# Out:
# '{"name": "Shubham", "age": 24, "education": null}'

# %%
json.loads(data)
# Out:
# {'name': 'Shubham', 'age': 24, 'education': None}

# %%
import requests

url = "https://imdb-top-100-movies.p.rapidapi.com/"

headers = {
	"x-rapidapi-key": "f372e3a161msh970c763b6342cdap1cf0dbjsn6f7cf846d191",
	"x-rapidapi-host": "imdb-top-100-movies.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# [{'rank': 1, 'title': 'The Shawshank Redemption', 'description': 'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.', 'image': 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_QL75_UX380_CR0,1,380,562_.jpg', 'big_image': 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@', 'genre': ['Drama'], 'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg', 'rating': '9.3', 'id': 'top1', 'year': 1994, 'imdbid': 'tt0111161', 'imdb_link': 'https://www.imdb.com/title/tt0111161'}, {'rank': 2, 'title': 'The Godfather', 'description': 'The aging patriarch of an organized crime dynasty in postwar New York City transfers control of his clandestine empire to his reluctant youngest son.', 'image': 'https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UY562_CR8,0,380,562_.jpg', 'big_image': 'https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UY562_CR8,0,380,562_.jpg', 'genre': ['Crime', 'Drama'], 'thumbnail': 'https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY67_CR1,0,45,67_AL_.jpg', 'rating': '9.2', 'id': 'top2', 'year': 1972, 'imdbid': 'tt0068646', 'imdb_link': 'https://www.imdb.com/title/tt0068646'}, {'rank': 3, 'title': 'The Dark Knight', 'description': 'When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.', 'image': 'https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_QL75_UX380_CR0,0,380,562_.jpg', 'big_image': 'https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_QL75_UX380_CR0,0,380,562_.jpg', 'genre': ['Action', 'Crime', 'Drama'], 'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_UX67_CR0,0,67,98_AL_.jpg', 'rating': '9.0', 'id': 'top3', 'year': 2008, 'imdbid': 'tt0468569', 'imdb_link': 'https://www.imdb.com/title/tt0468569'}, {'rank': 4, 'title': 'The Godfather Part II', 'description': 'The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate.', 'image': 'https://m.media-amazon.com/images/M/MV5BMWMwMGQzZTItY2JlNC00OWZiLWIyMDctNDk2ZDQ2YjRjMWQ0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UY562_CR7,0,380,562_.jpg', 'big_image': 'https://m.media-amazon.com/images/M/MV5BMWMwMGQzZTItY2JlNC00OWZiLWIyMDctNDk2ZDQ2YjRjMWQ0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UY562_CR7,0,380,562_.jpg', 'genre': ['Crime', 'Drama'], 'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMWMwMGQzZTItY2JlNC00OWZiLWIyMDctNDk2ZDQ2YjRjMWQ0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY67_CR1,0,45,67_AL_.jpg', 'rating': '9.0', 'id': 'top4', 'year': 1974, 'imdbid': 'tt0071562', 'imdb_link': 'https://www.imdb.com/title/tt0071562'}, {'rank': 5, 'title': '12 Angry Men', 'description': 'The jury in a New York City murder trial is frustrated by a single member whose skeptical caution forces them to more carefully consider the evidence before jumping to a hasty verdict.', 'image': 'https://m.media-amazon.com/images/M/MV5BMWU4N2FjNzYtNTVkNC00NzQ0LTg0MjAtYTJlMjFhNGUxZDFmXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_QL75_UX380_CR0,11,380,562_.jpg', 'big_image': 'https://m.media-amazon.com/images/M/MV5BMWU4N2FjNzYtNTVkNC00NzQ0LTg0MjAtYTJlMjFhNGUxZDFmXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_QL75_UX380_CR0,11,380,562_.jpg', 'genre': ['Crime', 'Drama'], 'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMWU4N2FjNzYtNTVkNC00NzQ0LTg0MjAt ...

# %%
data = response.json()

# %%
i = 0
n = len(data)
while i < n:
    print(data[i]["title"])
    i += 1
# Out:
# The Shawshank Redemption
# The Godfather
# The Dark Knight
# The Godfather Part II
# 12 Angry Men
# Schindler's List
# The Lord of the Rings: The Return of the King
# Pulp Fiction
# The Lord of the Rings: The Fellowship of the Ring
# The Good, the Bad and the Ugly
# Forrest Gump
# Fight Club
# The Lord of the Rings: The Two Towers
# Inception
# Star Wars: Episode V - The Empire Strikes Back
# The Matrix
# Goodfellas
# Spider-Man: Across the Spider-Verse
# Interstellar
# One Flew Over the Cuckoo's Nest
# Se7en
# It's a Wonderful Life
# Seven Samurai
# The Silence of the Lambs
# Saving Private Ryan
# City of God
# Life Is Beautiful
# The Green Mile
# Star Wars: Episode IV - A New Hope
# Terminator 2: Judgment Day
# Spirited Away
# Oppenheimer
# Harakiri
# Back to the Future
# The Pianist
# Psycho
# Parasite
# Gladiator
# The Lion King
# Léon: The Professional
# American History X
# The Departed
# Whiplash
# The Prestige
# The Usual Suspects
# Grave of the Fireflies
# Casablanca
# The Intouchables
# Modern Times
# Cinema Paradiso
# Once Upon a Time in the West
# Rear Window
# Alien
# City Lights
# Django Unchained
# Apocalypse Now
# Memento
# Indiana Jones and the Raiders of the Lost Ark
# WALL·E
# The Lives of Others
# Sunset Blvd.
# Paths of Glory
# Avengers: Infinity War
# The Shining
# The Great Dictator
# Witness for the Prosecution
# Spider-Man: Into the Spider-Verse
# Aliens
# Inglourious Basterds
# The Dark Knight Rises
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# Oldboy
# Coco
# Amadeus
# The Boat
# Avengers: Endgame
# Joker
# Your Name.
# 3 Idiots
# High and Low
# Capernaum
# Come and See
# Toy Story
# American Beauty
# Braveheart
# Princess Mononoke
# Good Will Hunting
# Once Upon a Time in America
# Singin' in the Rain
# Requiem for a Dream
# Toy Story 3
# Star Wars: Episode VI - Return of the Jedi
# Eternal Sunshine of the Spotless Mind
# 2001: A Space Odyssey
# The Hunt
# Reservoir Dogs
# Ikiru
# Lawrence of Arabia
# Citizen Kane
# M

# %%
import pandas

# %%
pandas.json_normalize(data)
# Out:
#     rank                     title  \
# 0      1  The Shawshank Redemption
# 1      2             The Godfather
# 2      3           The Dark Knight
# 3      4     The Godfather Part II
# 4      5              12 Angry Men
# ..   ...                       ...
# 95    96            Reservoir Dogs
# 96    97                     Ikiru
# 97    98        Lawrence of Arabia
# 98    99              Citizen Kane
# 99   100                         M
#
#                                           description  \
# 0   Two imprisoned men bond over a number of years...
# 1   The aging patriarch of an organized crime dyna...
# 2   When the menace known as the Joker wreaks havo...
# 3   The early life and career of Vito Corleone in ...
# 4   The jury in a New York City murder trial is fr...
# ..                                                ...
# 95  When a simple jewelry heist goes horribly wron...
# 96  A bureaucrat tries to find meaning in his life...
# 97  The story of T.E. Lawrence, the English office...
# 98  Following the death of publishing tycoon Charl...
# 99  When the police in a German city are unable to...
#
#                                                 image  \
# 0   https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1   https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3   https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4   https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                ...
# 95  https://m.media-amazon.com/images/M/MV5BZmExNm...
# 96  https://m.media-amazon.com/images/M/MV5BYWM1Ym...
# 97  https://m.media-amazon.com/images/M/MV5BYWY5Zj...
# 98  https://m.media-amazon.com/images/M/MV5BYjBiOT...
# 99  https://m.media-amazon.com/images/M/MV5BODA4OD...
#
#                                             big_image  \
# 0   https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1   https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3   https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4   https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                ...
# 95  https://m.media-amazon.com/images/M/MV5BZmExNm...
# 96  https://m.media-amazon.com/images/M/MV5BYWM1Ym...
# 97  https://m.media-amazon.com/images/M/MV5BYWY5Zj...
# 98  https://m.media-amazon.com/images/M/MV5BYjBiOT...
# 99  https://m.media-amazon.com/images/M/MV5BODA4OD...
#
#                             genre  \
# 0                         [Drama]
# 1                  [Crime, Drama]
# 2          [Action, Crime, Drama]
# 3                  [Crime, Drama]
# 4                  [Crime, Drama]
# ..                            ...
# 95              [Crime, Thriller]
# 96                        [Drama]
# 97  [Adventure, Biography, Drama]
# 98               [Drama, Mystery]
# 99     [Crime, Mystery, Thriller]
#
#                                             thumbnail rating      id  year  \
# 0   https://m.media-amazon.com/images/M/MV5BMDFkYT...    9.3    top1  1994
# 1   https://m.media-amazon.com/images/M/MV5BM2MyNj...    9.2    top2  1972
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...    9.0    top3  2008
# 3   https://m.media-amazon.com/images/M/MV5BMWMwMG...    9.0    top4  1974
# 4   https://m.media-amazon.com/images/M/MV5BMWU4N2...    9.0    top5  1957
# ..                                                ...    ...     ...   ...
# 95  https://m.media-amazon.com/images/M/MV5BZmExNm...    8.3   top96  1992
# 96  https://m.media-amazon.com/images/M/MV5BYWM1Ym...    8.3   top97  1952
# 97  https://m.media-amazon.com/images/M/MV5BYWY5Zj...    8.3   top98  1962
# 98  https://m.media-amazon.com/images/M/MV5BYjBiOT...    8.3   top99  1941
# 99  https://m.media-amazon.com/images/M/MV5BODA4OD...    8.3  top100  1931
#
#        imdbid                             imdb_link
# 0   tt0111161  https://www.imdb.com/title/tt0111161
# 1   tt0068646  https://www.imdb.com/title/tt0068646
# 2   tt0468569  https://www.imdb.com/title/tt0468569
# 3   tt0071562  https://www.imdb.com/title/tt0071562
# 4   tt0050083  https://www.imdb.com/title/tt0050083
# ..        ...                                   ...
# 95  tt0105236  https://www.imdb.com/title/tt0105236
# 96  tt0044741  https://www.imdb.com/title/tt0044741
# 97  tt0056172  https://www.imdb.com/title/tt0056172
# 98  tt0033467  https://www.imdb.com/title/tt0033467
# 99  tt0022100  https://www.imdb.com/title/tt0022100
#
# [100 rows x 12 columns]

# %%
import requests

url = "https://movies-ratings2.p.rapidapi.com/ratings"

querystring = {"id":"tt0111161"}

headers = {
	"x-rapidapi-key": "f372e3a161msh970c763b6342cdap1cf0dbjsn6f7cf846d191",
	"x-rapidapi-host": "movies-ratings2.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'tmdbId': 278, 'imdbId': 'tt0111161', 'lastUpdated': 1738173381282, 'ratings': {'imdb': {'score': 9.3, 'reviewsCount': 3000000, 'url': 'https://www.imdb.com/title/tt0111161/'}, 'metacritic': {'metascore': 82, 'userScore': 9.3, 'averageScore': 8.8, 'url': 'https://www.metacritic.com/movie/the-shawshank-redemption'}, 'rotten_tomatoes': {'tomatometer': 89, 'tomatometerReviewsCount': 146, 'audienceScore': 98, 'audienceScoreReviewsCount': 250000, 'averageScore': 9.4, 'url': 'https://www.rottentomatoes.com/m/shawshank_redemption'}, 'letterboxd': {'score': 4.6, 'url': 'https://letterboxd.com/film/the-shawshank-redemption'}, 'allocine': None, 'average': {'score': 9.12}}, 'media': {'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg', 'budget': 25000000, 'genres': [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name': 'Crime'}], 'homepage': '', 'id': 278, 'imdb_id': 'tt0111161', 'origin_country': ['US'], 'original_language': 'en', 'original_title': 'The Shawshank Redemption', 'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.', 'popularity': 173.309, 'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg', 'release_date': '1994-09-23', 'revenue': 28341469, 'runtime': 142, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': 'Fear can hold you prisoner. Hope can set you free.', 'title': 'The Shawshank Redemption', 'video': False, 'external_ids': {'imdb_id': 'tt0111161', 'wikidata_id': 'Q172241', 'facebook_id': None, 'instagram_id': None, 'twitter_id': None}, 'director': 'Frank Darabont', 'media_type': 'movie'}}

# %%
data = response.json()

# %%
len(data)
# Out:
# 5

# %%
data.keys()
# Out:
# dict_keys(['tmdbId', 'imdbId', 'lastUpdated', 'ratings', 'media'])

# %%
len(data['media'])
# Out:
# 23

# %%
data['media'].keys()
# Out:
# dict_keys(['backdrop_path', 'budget', 'genres', 'homepage', 'id', 'imdb_id', 'origin_country', 'original_language', 'original_title', 'overview', 'popularity', 'poster_path', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'video', 'external_ids', 'director', 'media_type'])

# %%
data['media']["original_title"]
# Out:
# 'The Shawshank Redemption'

# %%
pandas.json_normalize(data['media'])
# Out:
#                       backdrop_path    budget  \
# 0  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg  25000000
#
#                                               genres homepage   id    imdb_id  \
# 0  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...           278  tt0111161
#
#   origin_country original_language            original_title  \
# 0           [US]                en  The Shawshank Redemption
#
#                                             overview  ...  \
# 0  Imprisoned in the 1940s for the double murder ...  ...
#
#                                              tagline  \
# 0  Fear can hold you prisoner. Hope can set you f...
#
#                       title  video        director  media_type  \
# 0  The Shawshank Redemption  False  Frank Darabont       movie
#
#   external_ids.imdb_id external_ids.wikidata_id external_ids.facebook_id  \
# 0            tt0111161                  Q172241                     None
#
#   external_ids.instagram_id  external_ids.twitter_id
# 0                      None                     None
#
# [1 rows x 27 columns]

# %%
import requests

url = "https://movie-database-api1.p.rapidapi.com/list_movies.json"

querystring = {"limit":"20","page":"1","quality":"all","genre":"all","minimum_rating":"0","query_term":"0","sort_by":"date_added","order_by":"desc","with_rt_ratings":"false"}

headers = {
	"x-rapidapi-key": "f372e3a161msh970c763b6342cdap1cf0dbjsn6f7cf846d191",
	"x-rapidapi-host": "movie-database-api1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': 'ok', 'status_message': 'Query was successful', 'data': {'movie_count': 69695, 'limit': 20, 'page_number': 1, 'movies': [{'id': 70938, 'url': 'https://yts.mx/movies/blind-heat-2001', 'imdb_code': 'tt0236026', 'title': 'Blind Heat', 'title_english': 'Blind Heat', 'title_long': 'Blind Heat (2001)', 'slug': 'blind-heat-2001', 'year': 2001, 'rating': 4.2, 'runtime': 95, 'genres': ['Thriller'], 'summary': '', 'description_full': '', 'synopsis': '', 'yt_trailer_code': '', 'language': 'en', 'mpa_rating': '', 'background_image': 'https://yts.mx/assets/images/movies/blind_heat_2001/background.jpg', 'background_image_original': 'https://yts.mx/assets/images/movies/blind_heat_2001/background.jpg', 'small_cover_image': 'https://yts.mx/assets/images/movies/blind_heat_2001/small-cover.jpg', 'medium_cover_image': 'https://yts.mx/assets/images/movies/blind_heat_2001/medium-cover.jpg', 'large_cover_image': 'https://yts.mx/assets/images/movies/blind_heat_2001/large-cover.jpg', 'state': 'ok', 'torrents': [{'url': 'https://yts.mx/torrent/download/F84FF57FFC135783CF81BF34BEAF579DE72B53C4', 'hash': 'F84FF57FFC135783CF81BF34BEAF579DE72B53C4', 'quality': '480p', 'type': 'web', 'is_repack': '0', 'video_codec': 'x264', 'bit_depth': '8', 'audio_channels': '2.0', 'seeds': 0, 'peers': 0, 'size': '842.06 MB', 'size_bytes': 882963907, 'date_uploaded': '2025-08-27 17:20:54', 'date_uploaded_unix': 1756308054}]}, {'id': 70931, 'url': 'https://yts.mx/movies/dog-daze-1937', 'imdb_code': 'tt0028794', 'title': 'Dog Daze', 'title_english': 'Dog Daze', 'title_long': 'Dog Daze (1937)', 'slug': 'dog-daze-1937', 'year': 1937, 'rating': 5.9, 'runtime': 7, 'genres': ['Animation', 'Comedy', 'Family'], 'summary': '', 'description_full': '', 'synopsis': '', 'yt_trailer_code': '', 'language': 'en', 'mpa_rating': '', 'background_image': 'https://yts.mx/assets/images/movies/dog_daze_1937/background.jpg', 'background_image_original': 'https://yts.mx/assets/images/movies/dog_daze_1937/background.jpg', 'small_cover_image': 'https://yts.mx/assets/images/movies/dog_daze_1937/small-cover.jpg', 'medium_cover_image': 'https://yts.mx/assets/images/movies/dog_daze_1937/medium-cover.jpg', 'large_cover_image': 'https://yts.mx/assets/images/movies/dog_daze_1937/large-cover.jpg', 'state': 'ok', 'torrents': [{'url': 'https://yts.mx/torrent/download/A5C263C87126ED25258DE0F7CD2A106FC92ADD9B', 'hash': 'A5C263C87126ED25258DE0F7CD2A106FC92ADD9B', 'quality': '720p', 'type': 'bluray', 'is_repack': '0', 'video_codec': 'x264', 'bit_depth': '8', 'audio_channels': '2.0', 'seeds': 0, 'peers': 0, 'size': '63.4 MB', 'size_bytes': 66479718, 'date_uploaded': '2025-08-27 16:54:47', 'date_uploaded_unix': 1756306487}, {'url': 'https://yts.mx/torrent/download/693C1631E82295720C90D1C80F8A19822136E30E', 'hash': '693C1631E82295720C90D1C80F8A19822136E30E', 'quality': '1080p', 'type': 'bluray', 'is_repack': '0', 'video_codec': 'x264', 'bit_depth': '8', 'audio_channels': '2.0', 'seeds': 0, 'peers': 0, 'size': '117.76 MB', 'size_bytes': 123480310, 'date_uploaded': '2025-08-27 16:59:42', 'date_uploaded_unix': 1756306782}], 'date_uploaded': '2025-08-27 16:54:47', 'date_uploaded_unix': 1756306487}, {'id': 70924, 'url': 'https://yts.mx/movies/carmen-a-hip-hopera-2001', 'imdb_code': 'tt0274415', 'title': 'Carmen: A Hip Hopera', 'title_english': 'Carmen: A Hip Hopera', 'title_long': 'Carmen: A Hip Hopera (2001)', 'slug': 'carmen-a-hip-hopera-2001', 'year': 2001, 'rating': 4.7, 'runtime': 88, 'genres': ['Drama', 'Musical'], 'summary': '', 'description_full': '', 'synopsis': '', 'yt_trailer_code': '', 'language': 'en', 'mpa_rating': '', 'background_image': 'https://yts.mx/assets/images/movies/carmen_a_hip_hopera_2001/background.jpg', 'background_image_original': 'https://yts.mx/assets/images/movies/carmen_a_hip_hopera_2001/background.jpg', 'small_cover_image': 'https://yts.mx/assets/images/movies/carmen_a_hip_hopera_2001/small-cover.jpg', 'medium_cover_image': 'https://yts.mx/assets/images/movies/carmen_a_hip_hoper ...

# %%
data = response.json()

# %%
data.keys()
# Out:
# dict_keys(['status', 'status_message', 'data', '@meta'])

# %%
data["data"].keys()
# Out:
# dict_keys(['movie_count', 'limit', 'page_number', 'movies'])

# %%
pandas.json_normalize(data["data"]['movies'])
# Out:
#        id                                                url   imdb_code  \
# 0   70938              https://yts.mx/movies/blind-heat-2001   tt0236026
# 1   70931                https://yts.mx/movies/dog-daze-1937   tt0028794
# 2   70924     https://yts.mx/movies/carmen-a-hip-hopera-2001   tt0274415
# 3   70923         https://yts.mx/movies/bread-and-alley-1970   tt0066127
# 4   70919  https://yts.mx/movies/i%c2%b4ll-never-let-you-...  tt37543196
# 5   70916                  https://yts.mx/movies/tehran-2025  tt21818782
# 6   70915         https://yts.mx/movies/cousin-angelica-1974   tt0072030
# 7   70914         https://yts.mx/movies/in-the-rearview-2023  tt27531514
# 8   70913           https://yts.mx/movies/slocum-et-moi-2024  tt32264775
# 9   70912  https://yts.mx/movies/the-last-rhinos-a-new-ho...  tt37748266
# 10  70911                 https://yts.mx/movies/kingdom-2025  tt11773426
# 11  70910  https://yts.mx/movies/christopher-a-beautiful-...  tt33293194
# 12  70909  https://yts.mx/movies/fantasy-football-ruined-...  tt37038661
# 13  70908          https://yts.mx/movies/nashville-girl-1976   tt0074954
# 14  70907            https://yts.mx/movies/the-last-men-2023  tt18936232
# 15  70906                  https://yts.mx/movies/sketch-2024  tt26238710
# 16  70905                   https://yts.mx/movies/oh-hi-2025  tt33292655
# 17  70904  https://yts.mx/movies/buzz-house-the-movie-2-2025  tt36597161
# 18  70903                https://yts.mx/movies/son-saka-2020   tt9621290
# 19  70902  https://yts.mx/movies/hans-zimmer-hollywood-re...  tt22487634
#
#                                  title                       title_english  \
# 0                           Blind Heat                          Blind Heat
# 1                             Dog Daze                            Dog Daze
# 2                 Carmen: A Hip Hopera                Carmen: A Hip Hopera
# 3                      Bread and Alley                     Bread and Alley
# 4                I´ll Never Let You Go               I´ll Never Let You Go
# 5                               Tehran                              Tehran
# 6                      Cousin Angelica                     Cousin Angelica
# 7                      In the Rearview                     In the Rearview
# 8                        Slocum et moi                       Slocum et moi
# 9          The Last Rhinos: A New Hope         The Last Rhinos: A New Hope
# 10                             Kingdom                             Kingdom
# 11  Christopher: A Beautiful Real Life  Christopher: A Beautiful Real Life
# 12   Fantasy Football Ruined Our Lives   Fantasy Football Ruined Our Lives
# 13                      Nashville Girl                      Nashville Girl
# 14                        The Last Men                        The Last Men
# 15                              Sketch                              Sketch
# 16                             Oh, Hi!                             Oh, Hi!
# 17             Buzz House: The Movie 2             Buzz House: The Movie 2
# 18                            Son Saka                            Son Saka
# 19        Hans Zimmer: Hollywood Rebel        Hans Zimmer: Hollywood Rebel
#
#                                    title_long  \
# 0                           Blind Heat (2001)
# 1                             Dog Daze (1937)
# 2                 Carmen: A Hip Hopera (2001)
# 3                      Bread and Alley (1970)
# 4                I´ll Never Let You Go (2025)
# 5                               Tehran (2025)
# 6                      Cousin Angelica (1974)
# 7                      In the Rearview (2023)
# 8                        Slocum et moi (2024)
# 9          The Last Rhinos: A New Hope (2025)
# 10                             Kingdom (2025)
# 11  Christopher: A Beautiful Real Life (2025)
# 12   Fantasy Football Ruined Our Lives (2025)
# 13                      Nashville Girl (1976)
# 14                        The Last Men (2023)
# 15                              Sketch (2024)
# 16                             Oh, Hi! (2025)
# 17             Buzz House: The Movie 2 (2025)
# 18                            Son Saka (2020)
# 19        Hans Zimmer: Hollywood Rebel (2022)
#
#                                       slug  year  rating  runtime  ...  \
# 0                          blind-heat-2001  2001     4.2       95  ...
# 1                            dog-daze-1937  1937     5.9        7  ...
# 2                 carmen-a-hip-hopera-2001  2001     4.7       88  ...
# 3                     bread-and-alley-1970  1970     7.0       10  ...
# 4          i%c2%b4ll-never-let-you-go-2025  2025     6.2        0  ...
# 5                              tehran-2025  2025     6.7      115  ...
# 6                     cousin-angelica-1974  1974     7.3      107  ...
# 7                     in-the-rearview-2023  2023     7.5       84  ...
# 8                       slocum-et-moi-2024  2024     6.9       75  ...
# 9          the-last-rhinos-a-new-hope-2025  2025     6.2        0  ...
# 10                            kingdom-2025  2025     5.9      158  ...
# 11  christopher-a-beautiful-real-life-2025  2025     0.0        0  ...
# 12  fantasy-football-ruined-our-lives-2025  2025     0.0       90  ...
# 13                     nashville-girl-1976  1976     6.0       91  ...
# 14                       the-last-men-2023  2023     6.3      121  ...
# 15                             sketch-2024  2024     7.2       93  ...
# 16                              oh-hi-2025  2025     6.6       95  ...
# 17             buzz-house-the-movie-2-2025  2025     3.8       85  ...
# 18                           son-saka-2020  2020     4.4       92  ...
# 19        hans-zimmer-hollywood-rebel-2022  2022     7.3       60  ...
#
#    mpa_rating                                   background_image  \
# 0              https://yts.mx/assets/images/movies/blind_heat...
# 1              https://yts.mx/assets/images/movies/dog_daze_1...
# 2              https://yts.mx/assets/images/movies/carmen_a_h...
# 3              https://yts.mx/assets/images/movies/bread_and_...
# 4              https://yts.mx/assets/images/movies/i%c2%b4ll_...
# 5              https://yts.mx/assets/images/movies/tehran_202...
# 6              https://yts.mx/assets/images/movies/cousin_ang...
# 7              https://yts.mx/assets/images/movies/in_the_rea...
# 8              https://yts.mx/assets/images/movies/slocum_et_...
# 9              https://yts.mx/assets/images/movies/the_last_r...
# 10             https://yts.mx/assets/images/movies/kingdom_20...
# 11             https://yts.mx/assets/images/movies/christophe...
# 12             https://yts.mx/assets/images/movies/fantasy_fo...
# 13             https://yts.mx/assets/images/movies/nashville_...
# 14             https://yts.mx/assets/images/movies/the_last_m...
# 15             https://yts.mx/assets/images/movies/sketch_202...
# 16             https://yts.mx/assets/images/movies/oh_hi_2025...
# 17             https://yts.mx/assets/images/movies/buzz_house...
# 18             https://yts.mx/assets/images/movies/son_saka_2...
# 19             https://yts.mx/assets/images/movies/hans_zimme...
#
#                             background_image_original  \
# 0   https://yts.mx/assets/images/movies/blind_heat...
# 1   https://yts.mx/assets/images/movies/dog_daze_1...
# 2   https://yts.mx/assets/images/movies/carmen_a_h...
# 3   https://yts.mx/assets/images/movies/bread_and_...
# 4   https://yts.mx/assets/images/movies/i%c2%b4ll_...
# 5   https://yts.mx/assets/images/movies/tehran_202...
# 6   https://yts.mx/assets/images/movies/cousin_ang...
# 7   https://yts.mx/assets/images/movies/in_the_rea...
# 8   https://yts.mx/assets/images/movies/slocum_et_...
# 9   https://yts.mx/assets/images/movies/the_last_r...
# 10  https://yts.mx/assets/images/movies/kingdom_20...
# 11  https://yts.mx/assets/images/movies/christophe...
# 12  https://yts.mx/assets/images/movies/fantasy_fo...
# 13  https://yts.mx/assets/images/movies/nashville_...
# 14  https://yts.mx/assets/images/movies/the_last_m...
# 15  https://yts.mx/assets/images/movies/sketch_202...
# 16  https://yts.mx/assets/images/movies/oh_hi_2025...
# 17  https://yts.mx/assets/images/movies/buzz_house...
# 18  https://yts.mx/assets/images/movies/son_saka_2...
# 19  https://yts.mx/assets/images/movies/hans_zimme...
#
#                                     small_cover_image  \
# 0   https://yts.mx/assets/images/movies/blind_heat...
# 1   https://yts.mx/assets/images/movies/dog_daze_1...
# 2   https://yts.mx/assets/images/movies/carmen_a_h...
# 3   https://yts.mx/assets/images/movies/bread_and_...
# 4   https://yts.mx/assets/images/movies/i%c2%b4ll_...
# 5   https://yts.mx/assets/images/movies/tehran_202...
# 6   https://yts.mx/assets/images/movies/cousin_ang...
# 7   https://yts.mx/assets/images/movies/in_the_rea...
# 8   https://yts.mx/assets/images/movies/slocum_et_...
# 9   https://yts.mx/assets/images/movies/the_last_r...
# 10  https://yts.mx/assets/images/movies/kingdom_20...
# 11  https://yts.mx/assets/images/movies/christophe...
# 12  https://yts.mx/assets/images/movies/fantasy_fo...
# 13  https://yts.mx/assets/images/movies/nashville_...
# 14  https://yts.mx/assets/images/movies/the_last_m...
# 15  https://yts.mx/assets/images/movies/sketch_202...
# 16  https://yts.mx/assets/images/movies/oh_hi_2025...
# 17  https://yts.mx/assets/images/movies/buzz_house...
# 18  https://yts.mx/assets/images/movies/son_saka_2...
# 19  https://yts.mx/assets/images/movies/hans_zimme...
#
#                                    medium_cover_image  \
# 0   https://yts.mx/assets/images/movies/blind_heat...
# 1   https://yts.mx/assets/images/movies/dog_daze_1...
# 2   https://yts.mx/assets/images/movies/carmen_a_h...
# 3   https://yts.mx/assets/images/movies/bread_and_...
# 4   https://yts.mx/assets/images/movies/i%c2%b4ll_...
# 5   https://yts.mx/assets/images/movies/tehran_202...
# 6   https://yts.mx/assets/images/movies/cousin_ang...
# 7   https://yts.mx/assets/images/movies/in_the_rea...
# 8   https://yts.mx/assets/images/movies/slocum_et_...
# 9   https://yts.mx/assets/images/movies/the_last_r...
# 10  https://yts.mx/assets/images/movies/kingdom_20...
# 11  https://yts.mx/assets/images/movies/christophe...
# 12  https://yts.mx/assets/images/movies/fantasy_fo...
# 13  https://yts.mx/assets/images/movies/nashville_...
# 14  https://yts.mx/assets/images/movies/the_last_m...
# 15  https://yts.mx/assets/images/movies/sketch_202...
# 16  https://yts.mx/assets/images/movies/oh_hi_2025...
# 17  https://yts.mx/assets/images/movies/buzz_house...
# 18  https://yts.mx/assets/images/movies/son_saka_2...
# 19  https://yts.mx/assets/images/movies/hans_zimme...
#
#                                     large_cover_image state  \
# 0   https://yts.mx/assets/images/movies/blind_heat...    ok
# 1   https://yts.mx/assets/images/movies/dog_daze_1...    ok
# 2   https://yts.mx/assets/images/movies/carmen_a_h...    ok
# 3   https://yts.mx/assets/images/movies/bread_and_...    ok
# 4   https://yts.mx/assets/images/movies/i%c2%b4ll_...    ok
# 5   https://yts.mx/assets/images/movies/tehran_202...    ok
# 6   https://yts.mx/assets/images/movies/cousin_ang...    ok
# 7   https://yts.mx/assets/images/movies/in_the_rea...    ok
# 8   https://yts.mx/assets/images/movies/slocum_et_...    ok
# 9   https://yts.mx/assets/images/movies/the_last_r...    ok
# 10  https://yts.mx/assets/images/movies/kingdom_20...    ok
# 11  https://yts.mx/assets/images/movies/christophe...    ok
# 12  https://yts.mx/assets/images/movies/fantasy_fo...    ok
# 13  https://yts.mx/assets/images/movies/nashville_...    ok
# 14  https://yts.mx/assets/images/movies/the_last_m...    ok
# 15  https://yts.mx/assets/images/movies/sketch_202...    ok
# 16  https://yts.mx/assets/images/movies/oh_hi_2025...    ok
# 17  https://yts.mx/assets/images/movies/buzz_house...    ok
# 18  https://yts.mx/assets/images/movies/son_saka_2...    ok
# 19  https://yts.mx/assets/images/movies/hans_zimme...    ok
#
#                                              torrents        date_uploaded  \
# 0   [{'url': 'https://yts.mx/torrent/download/F84F...                  NaN
# 1   [{'url': 'https://yts.mx/torrent/download/A5C2...  2025-08-27 16:54:47
# 2   [{'url': 'https://yts.mx/torrent/download/6206...  2025-08-27 17:21:06
# 3   [{'url': 'https://yts.mx/torrent/download/2125...  2025-08-27 16:44:46
# 4   [{'url': 'https://yts.mx/torrent/download/6384...  2025-08-27 16:32:56
# 5   [{'url': 'https://yts.mx/torrent/download/8EF7...  2025-08-27 16:56:02
# 6   [{'url': 'https://yts.mx/torrent/download/5D0E...  2025-08-27 15:38:47
# 7   [{'url': 'https://yts.mx/torrent/download/8284...  2025-08-27 14:22:59
# 8   [{'url': 'https://yts.mx/torrent/download/1817...  2025-08-27 15:20:06
# 9   [{'url': 'https://yts.mx/torrent/download/FA72...  2025-08-27 14:04:59
# 10  [{'url': 'https://yts.mx/torrent/download/D4B1...  2025-08-27 12:19:09
# 11  [{'url': 'https://yts.mx/torrent/download/8D85...  2025-08-27 11:25:19
# 12  [{'url': 'https://yts.mx/torrent/download/F838...  2025-08-27 09:50:47
# 13  [{'url': 'https://yts.mx/torrent/download/6128...  2025-08-27 09:40:18
# 14  [{'url': 'https://yts.mx/torrent/download/C671...  2025-08-27 10:35:56
# 15  [{'url': 'https://yts.mx/torrent/download/5702...  2025-08-27 08:41:10
# 16  [{'url': 'https://yts.mx/torrent/download/DBAC...  2025-08-27 03:19:11
# 17  [{'url': 'https://yts.mx/torrent/download/FB63...  2025-08-27 00:20:36
# 18  [{'url': 'https://yts.mx/torrent/download/2218...  2025-08-26 19:21:23
# 19  [{'url': 'https://yts.mx/torrent/download/99AC...  2025-08-26 16:23:27
#
#    date_uploaded_unix
# 0                 NaN
# 1        1.756306e+09
# 2        1.756308e+09
# 3        1.756306e+09
# 4        1.756305e+09
# 5        1.756307e+09
# 6        1.756302e+09
# 7        1.756297e+09
# 8        1.756301e+09
# 9        1.756296e+09
# 10       1.756290e+09
# 11       1.756287e+09
# 12       1.756281e+09
# 13       1.756280e+09
# 14       1.756284e+09
# 15       1.756277e+09
# 16       1.756258e+09
# 17       1.756247e+09
# 18       1.756229e+09
# 19       1.756218e+09
#
# [20 rows x 26 columns]

# %%
print("GET", "POST", "PUT/PATCH", "DELETE")
# Out:
# GET POST PUT/PATCH DELETE

# %%
import http.client

conn = http.client.HTTPSConnection("zillow56.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "f372e3a161msh970c763b6342cdap1cf0dbjsn6f7cf846d191",
    'x-rapidapi-host': "zillow56.p.rapidapi.com"
}

conn.request("GET", "/search?location=houston%2C%20tx&output=json&status=forSale&sortSelection=priorityscore&listing_type=by_agent&doz=any", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"results":[{"bathrooms":2.0,"bedrooms":3.0,"city":"Houston","country":"USA","currency":"USD","daysOnZillow":-1,"homeStatus":"FOR_SALE","homeStatusForHDP":"FOR_SALE","homeType":"SINGLE_FAMILY","imgSrc":"https://photos.zillowstatic.com/fp/e3ae17045bac31ca3dda1575e30b32d3-p_e.jpg","isFeatured":false,"isNonOwnerOccupied":true,"isPreforeclosureAuction":false,"isPremierBuilder":false,"isShowcaseListing":true,"isUnmappable":false,"isZillowOwned":false,"latitude":29.933577,"listing_sub_type":{"is_FSBA":true},"livingArea":2477.0,"longitude":-95.66908,"lotAreaUnit":"sqft","lotAreaValue":9169.38,"price":410000.0,"priceForHDP":410000.0,"rentZestimate":2895,"shouldHighlight":false,"state":"TX","streetAddress":"11030 Acanthus Ln","taxAssessedValue":408862.0,"timeOnZillow":763315000,"zestimate":403400,"zipcode":"77095","zpid":55481338},{"bathrooms":2.0,"bedrooms":3.0,"city":"Houston","country":"USA","currency":"USD","datePriceChanged":1755586800000,"daysOnZillow":-1,"homeStatus":"FOR_SALE","homeStatusForHDP":"FOR_SALE","homeType":"SINGLE_FAMILY","imgSrc":"https://photos.zillowstatic.com/fp/0c5ac8c64e0b620871f8b53cdc84dbb5-p_e.jpg","isFeatured":false,"isNonOwnerOccupied":true,"isPreforeclosureAuction":false,"isPremierBuilder":false,"isShowcaseListing":true,"isUnmappable":false,"isZillowOwned":false,"latitude":29.833223,"listing_sub_type":{"is_FSBA":true},"livingArea":1703.0,"longitude":-95.4008,"lotAreaUnit":"acres","lotAreaValue":0.2883,"price":325000.0,"priceChange":-10000,"priceForHDP":325000.0,"priceReduction":"$10,000 (Aug 19)","rentZestimate":2032,"shouldHighlight":false,"state":"TX","streetAddress":"127 E Thornton Rd","taxAssessedValue":358727.0,"timeOnZillow":690605000,"zestimate":324100,"zipcode":"77022","zpid":28031490},{"bathrooms":3.0,"bedrooms":3.0,"city":"Houston","country":"USA","currency":"USD","daysOnZillow":-1,"homeStatus":"FOR_SALE","homeStatusForHDP":"FOR_SALE","homeType":"SINGLE_FAMILY","imgSrc":"https://photos.zillowstatic.com/fp/d601d7842f37d50b166daa5c0fe5bce3-p_e.jpg","isFeatured":false,"isNonOwnerOccupied":true,"isPreforeclosureAuction":false,"isPremierBuilder":false,"isShowcaseListing":true,"isUnmappable":false,"isZillowOwned":false,"latitude":29.846794,"listing_sub_type":{"is_newHome":true,"is_openHouse":true},"livingArea":1627.0,"longitude":-95.44796,"lotAreaUnit":"sqft","lotAreaValue":1890.504,"newConstructionType":"BUILDER_SPEC","openHouse":"Sat. 1-4pm","open_house_info":{"open_house_showing":[{"open_house_end":1756594800000,"open_house_start":1756584000000},{"open_house_end":1756681200000,"open_house_start":1756670400000}]},"price":369000.0,"priceForHDP":369000.0,"shouldHighlight":false,"state":"TX","streetAddress":"2582 W Tidwell Rd","timeOnZillow":608060000,"zipcode":"77091","zpid":456111779},{"bathrooms":4.0,"bedrooms":5.0,"city":"Houston","country":"USA","currency":"USD","datePriceChanged":1744182000000,"daysOnZillow":-1,"homeStatus":"FOR_SALE","homeStatusForHDP":"FOR_SALE","homeType":"SINGLE_FAMILY","imgSrc":"https://photos.zillowstatic.com/fp/c1de09c0920b6e986625d0de0a7716c1-p_e.jpg","isFeatured":false,"isNonOwnerOccupied":true,"isPreforeclosureAuction":false,"isPremierBuilder":false,"isShowcaseListing":false,"isUnmappable":false,"isZillowOwned":false,"latitude":30.009228,"listing_sub_type":{"is_FSBA":true},"livingArea":3560.0,"longitude":-95.38549,"lotAreaUnit":"sqft","lotAreaValue":8681.508,"price":280000.0,"priceChange":-15000,"priceForHDP":280000.0,"priceReduction":"","rentZestimate":2685,"shouldHighlight":false,"state":"TX","streetAddress":"2739 Blue Glen Ln","taxAssessedValue":316957.0,"timeOnZillow":2766027000,"zipcode":"77073","zpid":28354296},{"bathrooms":3.0,"bedrooms":4.0,"city":"Houston","country":"USA","currency":"USD","daysOnZillow":-1,"homeStatus":"FOR_SALE","homeStatusForHDP":"FOR_SALE","homeType":"SINGLE_FAMILY","imgSrc":"https://photos.zillowstatic.com/fp/1a112cccb3e481aa09cf5ef7ef9ac532-p_e.jpg","isFeatured":false,"isNonOwnerOccupied":true,"isPreforeclosureAuction":false,"isPremierBuil ...

# %%
import json

# %%
data = json.loads(data.decode("utf-8"))

# %%
res.status
# Out:
# 200

# %%
print(res.headers)
# Out:
# Date: Wed, 27 Aug 2025 17:12:12 GMT
# Content-Type: application/json
# Content-Length: 35564
# Connection: keep-alive
# X-RateLimit-rapid-free-plans-hard-limit-Limit: 500000
# X-RateLimit-rapid-free-plans-hard-limit-Remaining: 499998
# X-RateLimit-rapid-free-plans-hard-limit-Reset: 1866318
# X-RateLimit-Requests-Limit: 30
# X-RateLimit-Requests-Remaining: 28
# X-RateLimit-Requests-Reset: 1866318
# Server: RapidAPI-1.2.8
# X-RapidAPI-Version: 1.2.8
# X-RapidAPI-Region: AWS - ap-southeast-1
# X-RapidAPI-Request-Id: 3de0cd600c94c4a8c34a6650b29757171d0de55cf1a2733481d166031b52f36c

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['results', 'resultsPerPage', 'totalPages', 'totalResultCount'])

# %%
import pandas

# %%
pandas.json_normalize(data['results'])
# Out:
#     bathrooms  bedrooms     city country currency  daysOnZillow homeStatus  \
# 0         2.0       3.0  Houston     USA      USD            -1   FOR_SALE
# 1         2.0       3.0  Houston     USA      USD            -1   FOR_SALE
# 2         3.0       3.0  Houston     USA      USD            -1   FOR_SALE
# 3         4.0       5.0  Houston     USA      USD            -1   FOR_SALE
# 4         3.0       4.0  Houston     USA      USD            -1   FOR_SALE
# 5         3.0       5.0  Houston     USA      USD            -1   FOR_SALE
# 6         3.0       4.0  Houston     USA      USD            -1   FOR_SALE
# 7         3.0       5.0  Houston     USA      USD            -1   FOR_SALE
# 8         3.0       3.0  Houston     USA      USD            -1   FOR_SALE
# 9         3.0       5.0  Houston     USA      USD            -1   FOR_SALE
# 10        5.0       4.0  Houston     USA      USD            -1   FOR_SALE
# 11        2.0       3.0  Houston     USA      USD            -1   FOR_SALE
# 12        2.0       3.0  Houston     USA      USD            -1   FOR_SALE
# 13        4.0       4.0  Houston     USA      USD            -1   FOR_SALE
# 14        4.0       4.0  Houston     USA      USD            -1   FOR_SALE
# 15        2.0       3.0  Houston     USA      USD            -1   FOR_SALE
# 16        2.0       3.0  Houston     USA      USD            -1   FOR_SALE
# 17        3.0       4.0  Houston     USA      USD            -1   FOR_SALE
# 18        4.0       4.0  Houston     USA      USD            -1   FOR_SALE
# 19        5.0       5.0  Houston     USA      USD            -1   FOR_SALE
# 20        5.0       5.0  Houston     USA      USD            -1   FOR_SALE
# 21        3.0       4.0  Houston     USA      USD            -1   FOR_SALE
# 22        2.0       3.0  Houston     USA      USD            -1   FOR_SALE
# 23        2.0       3.0  Houston     USA      USD            -1   FOR_SALE
# 24        2.0       4.0  Houston     USA      USD            -1   FOR_SALE
# 25        3.0       3.0  Houston     USA      USD            -1   FOR_SALE
# 26        3.0       4.0  Houston     USA      USD            -1   FOR_SALE
# 27        3.0       4.0  Houston     USA      USD            -1   FOR_SALE
# 28        2.0       2.0  Houston     USA      USD            -1   FOR_SALE
# 29        5.0       5.0  Houston     USA      USD            -1   FOR_SALE
# 30        3.0       3.0  Houston     USA      USD            -1   FOR_SALE
# 31        3.0       4.0  Houston     USA      USD            -1   FOR_SALE
# 32        3.0       4.0  Houston     USA      USD            -1   FOR_SALE
# 33        2.0       2.0  Houston     USA      USD            -1   FOR_SALE
# 34        4.0       3.0  Houston     USA      USD            -1   FOR_SALE
# 35        2.0       3.0  Houston     USA      USD            -1   FOR_SALE
# 36        2.0       3.0  Houston     USA      USD            -1   FOR_SALE
# 37        2.0       3.0  Houston     USA      USD            -1   FOR_SALE
# 38        1.0       3.0  Houston     USA      USD            -1   FOR_SALE
# 39        2.0       4.0  Houston     USA      USD            -1   FOR_SALE
# 40        3.0       2.0  Houston     USA      USD            -1   FOR_SALE
#
#    homeStatusForHDP       homeType  \
# 0          FOR_SALE  SINGLE_FAMILY
# 1          FOR_SALE  SINGLE_FAMILY
# 2          FOR_SALE  SINGLE_FAMILY
# 3          FOR_SALE  SINGLE_FAMILY
# 4          FOR_SALE  SINGLE_FAMILY
# 5          FOR_SALE  SINGLE_FAMILY
# 6          FOR_SALE  SINGLE_FAMILY
# 7          FOR_SALE  SINGLE_FAMILY
# 8          FOR_SALE  SINGLE_FAMILY
# 9          FOR_SALE  SINGLE_FAMILY
# 10         FOR_SALE      TOWNHOUSE
# 11         FOR_SALE  SINGLE_FAMILY
# 12         FOR_SALE  SINGLE_FAMILY
# 13         FOR_SALE  SINGLE_FAMILY
# 14         FOR_SALE  SINGLE_FAMILY
# 15         FOR_SALE  SINGLE_FAMILY
# 16         FOR_SALE  SINGLE_FAMILY
# 17         FOR_SALE  SINGLE_FAMILY
# 18         FOR_SALE  SINGLE_FAMILY
# 19         FOR_SALE  SINGLE_FAMILY
# 20         FOR_SALE  SINGLE_FAMILY
# 21         FOR_SALE  SINGLE_FAMILY
# 22         FOR_SALE      TOWNHOUSE
# 23         FOR_SALE  SINGLE_FAMILY
# 24         FOR_SALE  SINGLE_FAMILY
# 25         FOR_SALE  SINGLE_FAMILY
# 26         FOR_SALE  SINGLE_FAMILY
# 27         FOR_SALE  SINGLE_FAMILY
# 28         FOR_SALE      TOWNHOUSE
# 29         FOR_SALE  SINGLE_FAMILY
# 30         FOR_SALE  SINGLE_FAMILY
# 31         FOR_SALE  SINGLE_FAMILY
# 32         FOR_SALE  SINGLE_FAMILY
# 33         FOR_SALE      TOWNHOUSE
# 34         FOR_SALE  SINGLE_FAMILY
# 35         FOR_SALE      TOWNHOUSE
# 36         FOR_SALE  SINGLE_FAMILY
# 37         FOR_SALE  SINGLE_FAMILY
# 38         FOR_SALE  SINGLE_FAMILY
# 39         FOR_SALE  SINGLE_FAMILY
# 40         FOR_SALE          CONDO
#
#                                                imgSrc  ...    priceReduction  \
# 0   https://photos.zillowstatic.com/fp/e3ae17045ba...  ...               NaN
# 1   https://photos.zillowstatic.com/fp/0c5ac8c64e0...  ...  $10,000 (Aug 19)
# 2   https://photos.zillowstatic.com/fp/d601d7842f3...  ...               NaN
# 3   https://photos.zillowstatic.com/fp/c1de09c0920...  ...
# 4   https://photos.zillowstatic.com/fp/1a112cccb3e...  ...               NaN
# 5   https://photos.zillowstatic.com/fp/05775af6fdb...  ...   $8,000 (Aug 12)
# 6   https://photos.zillowstatic.com/fp/9bfeb00fe52...  ...               NaN
# 7   https://photos.zillowstatic.com/fp/0828aa773f1...  ...   $7,000 (Aug 14)
# 8   https://photos.zillowstatic.com/fp/cea3356e248...  ...               NaN
# 9   https://photos.zillowstatic.com/fp/daf5863666e...  ...               NaN
# 10  https://photos.zillowstatic.com/fp/c3a31aa3bbc...  ...  $13,999 (Aug 22)
# 11  https://photos.zillowstatic.com/fp/4eb1b4d040d...  ...               NaN
# 12  https://photos.zillowstatic.com/fp/1774ace95b1...  ...               NaN
# 13  https://photos.zillowstatic.com/fp/2f7bca885bf...  ...               NaN
# 14  https://photos.zillowstatic.com/fp/3d54f9fa0b3...  ...   $5,000 (Aug 14)
# 15  https://photos.zillowstatic.com/fp/bd3543343f3...  ...               NaN
# 16  https://photos.zillowstatic.com/fp/2e002f3fd6f...  ...               NaN
# 17  https://photos.zillowstatic.com/fp/793e6b8309d...  ...               NaN
# 18  https://photos.zillowstatic.com/fp/c8b63237822...  ...               NaN
# 19  https://photos.zillowstatic.com/fp/4658a0a6513...  ...               NaN
# 20  https://photos.zillowstatic.com/fp/2ff964e0b15...  ...               NaN
# 21  https://photos.zillowstatic.com/fp/faf8d54421e...  ...               NaN
# 22  https://photos.zillowstatic.com/fp/26a8964356e...  ...   $5,000 (Aug 20)
# 23  https://photos.zillowstatic.com/fp/cb1d9eb083b...  ...               NaN
# 24  https://photos.zillowstatic.com/fp/c4bf67e2806...  ...               NaN
# 25  https://photos.zillowstatic.com/fp/5e34f1766ad...  ...   $9,901 (Aug 27)
# 26  https://photos.zillowstatic.com/fp/5f09449a21c...  ...               NaN
# 27  https://photos.zillowstatic.com/fp/4ef6b24c5f3...  ...               NaN
# 28  https://photos.zillowstatic.com/fp/59cdbb41006...  ...               NaN
# 29  https://photos.zillowstatic.com/fp/ac2bfd885a6...  ...               NaN
# 30  https://photos.zillowstatic.com/fp/a15ecc73f81...  ...  $20,000 (Aug 27)
# 31  https://photos.zillowstatic.com/fp/5724af19ab3...  ...               NaN
# 32  https://photos.zillowstatic.com/fp/cd49ae13ad6...  ...               NaN
# 33  https://photos.zillowstatic.com/fp/ebc68c3da11...  ...               NaN
# 34  https://photos.zillowstatic.com/fp/4fd92aa403b...  ...  $20,001 (Aug 27)
# 35  https://photos.zillowstatic.com/fp/fc13b419dab...  ...               NaN
# 36  https://photos.zillowstatic.com/fp/f0dff528dce...  ...               NaN
# 37  https://photos.zillowstatic.com/fp/4c3ba7a1d5e...  ...               NaN
# 38  https://photos.zillowstatic.com/fp/40694b42aa7...  ...               NaN
# 39  https://photos.zillowstatic.com/fp/6a1e08bc229...  ...               NaN
# 40  https://photos.zillowstatic.com/fp/3c6f01fa8ea...  ...               NaN
#
#     newConstructionType    openHouse  listing_sub_type.is_newHome  \
# 0                   NaN          NaN                          NaN
# 1                   NaN          NaN                          NaN
# 2          BUILDER_SPEC   Sat. 1-4pm                         True
# 3                   NaN          NaN                          NaN
# 4          BUILDER_SPEC          NaN                         True
# 5                   NaN          NaN                          NaN
# 6                   NaN          NaN                          NaN
# 7          BUILDER_SPEC          NaN                         True
# 8          BUILDER_SPEC          NaN                         True
# 9                   NaN          NaN                          NaN
# 10                  NaN          NaN                          NaN
# 11                  NaN          NaN                          NaN
# 12                  NaN   Sat. 2-4pm                          NaN
# 13                  NaN          NaN                          NaN
# 14                  NaN          NaN                          NaN
# 15                  NaN          NaN                          NaN
# 16                  NaN  Sun. 12-2pm                          NaN
# 17                  NaN          NaN                          NaN
# 18                  NaN          NaN                          NaN
# 19                  NaN          NaN                          NaN
# 20                  NaN          NaN                          NaN
# 21         BUILDER_SPEC          NaN                         True
# 22                  NaN          NaN                          NaN
# 23                  NaN          NaN                          NaN
# 24                  NaN          NaN                          NaN
# 25                  NaN          NaN                          NaN
# 26                  NaN          NaN                          NaN
# 27                  NaN          NaN                          NaN
# 28                  NaN          NaN                          NaN
# 29                  NaN          NaN                          NaN
# 30                  NaN          NaN                          NaN
# 31                  NaN          NaN                          NaN
# 32         BUILDER_SPEC          NaN                         True
# 33                  NaN          NaN                          NaN
# 34                  NaN  Sat. 12-3pm                          NaN
# 35                  NaN          NaN                          NaN
# 36                  NaN          NaN                          NaN
# 37                  NaN          NaN                          NaN
# 38                  NaN          NaN                          NaN
# 39                  NaN          NaN                          NaN
# 40                  NaN          NaN                          NaN
#
#     listing_sub_type.is_openHouse  \
# 0                             NaN
# 1                             NaN
# 2                            True
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 7                             NaN
# 8                             NaN
# 9                             NaN
# 10                            NaN
# 11                            NaN
# 12                           True
# 13                            NaN
# 14                            NaN
# 15                            NaN
# 16                           True
# 17                            NaN
# 18                            NaN
# 19                            NaN
# 20                            NaN
# 21                            NaN
# 22                            NaN
# 23                            NaN
# 24                            NaN
# 25                            NaN
# 26                            NaN
# 27                            NaN
# 28                            NaN
# 29                            NaN
# 30                            NaN
# 31                            NaN
# 32                            NaN
# 33                            NaN
# 34                           True
# 35                            NaN
# 36                            NaN
# 37                            NaN
# 38                            NaN
# 39                            NaN
# 40                            NaN
#
#                    open_house_info.open_house_showing     unit  \
# 0                                                 NaN      NaN
# 1                                                 NaN      NaN
# 2   [{'open_house_end': 1756594800000, 'open_house...      NaN
# 3                                                 NaN      NaN
# 4                                                 NaN      NaN
# 5                                                 NaN      NaN
# 6                                                 NaN      NaN
# 7                                                 NaN      NaN
# 8                                                 NaN      NaN
# 9                                                 NaN      NaN
# 10                                                NaN      NaN
# 11                                                NaN      NaN
# 12  [{'open_house_end': 1756594800000, 'open_house...      NaN
# 13                                                NaN      NaN
# 14                                                NaN      NaN
# 15                                                NaN      NaN
# 16  [{'open_house_end': 1756674000000, 'open_house...      NaN
# 17                                                NaN      NaN
# 18                                                NaN      NaN
# 19                                                NaN      NaN
# 20                                                NaN      NaN
# 21                                                NaN      NaN
# 22                                                NaN      # C
# 23                                                NaN      NaN
# 24                                                NaN      NaN
# 25                                                NaN      NaN
# 26                                                NaN      NaN
# 27                                                NaN      NaN
# 28                                                NaN   Apt 13
# 29                                                NaN      NaN
# 30                                                NaN      NaN
# 31                                                NaN      NaN
# 32                                                NaN      NaN
# 33                                                NaN  Apt 822
# 34  [{'open_house_end': 1756591200000, 'open_house...      # F
# 35                                                NaN   Unit C
# 36                                                NaN      NaN
# 37                                                NaN      NaN
# 38                                                NaN      NaN
# 39                                                NaN      NaN
# 40                                                NaN    # 202
#
#     listing_sub_type.is_FSBO  isRentalWithBasePrice  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN
# 5                        NaN                    NaN
# 6                        NaN                    NaN
# 7                        NaN                    NaN
# 8                        NaN                    NaN
# 9                        NaN                    NaN
# 10                       NaN                    NaN
# 11                       NaN                    NaN
# 12                       NaN                    NaN
# 13                       NaN                    NaN
# 14                       NaN                    NaN
# 15                       NaN                    NaN
# 16                       NaN                    NaN
# 17                       NaN                    NaN
# 18                       NaN                    NaN
# 19                       NaN                    NaN
# 20                       NaN                    NaN
# 21                       NaN                    NaN
# 22                       NaN                    NaN
# 23                       NaN                    NaN
# 24                      True                    NaN
# 25                       NaN                    NaN
# 26                       NaN                    NaN
# 27                       NaN                    NaN
# 28                       NaN                    NaN
# 29                       NaN                   True
# 30                       NaN                    NaN
# 31                       NaN                    NaN
# 32                       NaN                    NaN
# 33                       NaN                    NaN
# 34                       NaN                    NaN
# 35                       NaN                    NaN
# 36                       NaN                    NaN
# 37                       NaN                    NaN
# 38                       NaN                    NaN
# 39                       NaN                    NaN
# 40                       NaN                    NaN
#
#     listing_sub_type.is_forAuction
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN
# 10                             NaN
# 11                             NaN
# 12                             NaN
# 13                             NaN
# 14                             NaN
# 15                             NaN
# 16                             NaN
# 17                             NaN
# 18                             NaN
# 19                             NaN
# 20                             NaN
# 21                             NaN
# 22                             NaN
# 23                             NaN
# 24                             NaN
# 25                             NaN
# 26                             NaN
# 27                             NaN
# 28                             NaN
# 29                            True
# 30                             NaN
# 31                             NaN
# 32                             NaN
# 33                             NaN
# 34                             NaN
# 35                             NaN
# 36                             NaN
# 37                             NaN
# 38                             NaN
# 39                             NaN
# 40                             NaN
#
# [41 rows x 46 columns]
